# %%
# https://medium.com/@yanlinc/how-to-build-a-lda-topic-model-using-from-text-601cdcbfd3a6
# import all the necessary libraries
# import all the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from sklearn.cluster import DBSCAN
import string
import unicodedata
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy

# %%
# loading the dataset
train=pd.read_csv("quora.csv")

# %%
train.head()
# Out:
#                                             question  Unnamed: 1
# 0  What is the step by step guide to invest in sh...         NaN
# 1  What is the story of Kohinoor (Koh-i-Noor) Dia...         NaN
# 2  How can I increase the speed of my internet co...         NaN
# 3  Why am I mentally very lonely? How can I solve...         NaN
# 4  Which one dissolve in water quikly sugar, salt...         NaN

# %%
train["question"].head()
# Out:
# 0    What is the step by step guide to invest in sh...
# 1    What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2    How can I increase the speed of my internet co...
# 3    Why am I mentally very lonely? How can I solve...
# 4    Which one dissolve in water quikly sugar, salt...
# Name: question, dtype: object

# %%
#convert each question to a list of string
data = pd.Series(train["question"].tolist()).astype(str)

# %%
data = data[:500]

# %% [markdown]
# ## Text Preprocessing

# %%
# Text Preprocessing
nlp = spacy.load('en_core_web_sm')
stop_list = ['best','different',"won\'t", "couldn\'t", "mustn\'t", "didn\'t", "dtype object"]
for word in stop_list:
    spacy.lang.en.stop_words.STOP_WORDS.add(word)
    nlp.vocab[word].is_stop = True

# %%
# Preprocess the text data
def normalize(data):
    """Run all the functions for preprocessing in a pipeline"""
    clean_data = re.sub(re.compile('<.*?>'), '', data)
    cleaned_list = [ unicodedata.normalize('NFKD', word.text).encode('ascii', 'ignore').decode('utf-8', 'ignore') for word in  nlp(clean_data)]
    cleaned_list = " ".join(cleaned_list)
    cleaned_list = [word.text.rstrip('0123456789').lower() for word in nlp(cleaned_list) if word.pos_  in ['NOUN','PROPN', 'VERB'] and not word.is_digit and not word.is_punct and not word.is_stop ]
    return cleaned_list

# %%
# Preprocess the text data
normalized_data = []
for i, batch in data.groupby(np.arange(len(data)) // 10):
    for batch_data in batch:
        normalized_data.append(normalize(batch_data))

# %%
normalized_data
# Out:
# [['step', 'step', 'guide', 'invest', 'share', 'market', 'india'],
#  ['story', 'kohinoor', 'koh', 'noor', 'diamond'],
#  ['increase', 'speed', 'internet', 'connection', 'vpn'],
#  ['solve'],
#  ['dissolve', 'water', 'sugar', 'salt', 'methane', 'carbon', 'oxide'],
#  ['astrology', 'capricorn', 'sun', 'cap', 'moon', 'cap', 'rising'],
#  ['buy', 'tiago'],
#  ['geologist'],
#  ['use'],
#  ['motorola', 'company', 'hack', 'charter', 'motorolla', 'dcx'],
#  ['method', 'find', 'separation', 'slits', 'fresnel', 'biprism'],
#  ['read', 'find', 'youtube', 'comments'],
#  ['physics', 'learn'],
#  ['experience'],
#  ['laws',
#   'change',
#   'status',
#   'student',
#   'visa',
#   'card',
#   'compare',
#   'immigration',
#   'laws',
#   'canada'],
#  ['trump', 'presidency', 'mean', 'master', 'students', 'f', 'visa'],
#  ['manipulation', 'mean'],
#  ['girls', 'want', 'friends', 'guy', 'reject'],
#  ['quora', 'users', 'posting', 'questions', 'answered', 'google'],
#  ['marketing', 'institution', 'banglore'],
#  ['rockets', 'look'],
#  ['causing'],
#  ['questions', 'ask', 'quora'],
#  ['kv', 'hp'],
#  ['mean', 'time', 'look', 'clock', 'numbers'],
#  ['tips', 'making', 'job', 'interview', 'process', 'medicines'],
#  ['web', 'application'],
#  ['society', 'place', 'importance', 'sports'],
#  ['way', 'money'],
#  ['prepare', 'law'],
#  ['thing', 'like'],
#  ['cares', 'nose', 'gets', 'night'],
#  ['game', 'thrones', 'villain', 'mercy'],
#  ['united',
#   'states',
#   'government',
#   'blacklist',
#   'employment',
#   'united',
#   'states',
#   'citizens',
#   'views'],
#  ['travel', 'website', 'spain'],
#  ['people', 'think', 'obama', 'try', 'guns'],
#  ['improve', 'skills', 'entrepreneur', 'years'],
#  ['girlfriend', 'asks', 'boyfriend', 'choose', 'makes', 'want', 'reply'],
#  ['prepare', 'upsc'],
#  ['stall', 'speed', 'aoa', 'f-', 'wings', 'swept'],
#  ['slavs', 'squat'],
#  ['expect', 'confirmation', 'mail'],
#  ['month', 'day', 'trading'],
#  ['kid', 'rebel', 'worth', 'run'],
#  ['universities', 'rexnord', 'grads', 'majors', 'looking'],
#  ['way', 'increase', 'instagram', 'followers'],
#  ['darth', 'vader', 'fought', 'darth', 'maul', 'star', 'wars', 'legends'],
#  ['stages', 'breaking', 'couple', 'mean', 'happens', 'breaking'],
#  ['examples', 'products', 'oil'],
#  ['friends'],
#  ['career', 'launcher', 'rbi', 'grade', 'b', 'preparation'],
#  ['blu', 'ray', 'play', 'dvd', 'player'],
#  [],
#  ['thing', 've', 'eaten'],
#  ['gst', 'affects', 'cas', 'tax', 'officers'],
#  ['rsi'],
#  ['friend'],
#  ['rap', 'songs', 'dance'],
#  ['logged',
#   'gmail',
#   'remember',
#   'gmail',
#   'password',
#   'realized',
#   'recovery',
#   'email'],
#  ['ways', 'learn', 'french'],
#  ['download', 'content', 'kickass', 'torrent', 'registration'],
#  ['ring', 'iris', 'eye'],
#  ['harry', 'potter', 'book', 'harry', 'potter', 'cursed', 'child'],
#  [],
#  ['find', 'family', 'office', 'database'],
#  ['java', 'programming', 'learn', 'java', 'programming', 'language'],
#  ['book'],
#  ['store', 'energy', 'produced', 'lightning'],
#  ['review', 'performance', 'testing'],
#  ['cost', 'privacy', 'germany', 'come', 'lost', 'gain', 'privacy'],
#  ['types', 'immunity'],
#  ['personality', 'disorder'],
#  ['speak', 'english'],
#  ['quickbooks',
#   'auto',
#   'data',
#   'recovery',
#   'support',
#   'phone',
#   'number',
#   'recover',
#   'corrupted',
#   'data',
#   'files'],
#  ['gambler', 'time', 'reach', 'level'],
#  ['fire', 'bullet', 'aircraft', 'going', 'bullet', 'bullet', 'going'],
#  ['prevent', 'breast', 'cancer'],
#  ['log', 'gmail', 'account', 'friend', 'phone'],
#  ['money', 'internet'],
#  ['purpose', 'life'],
#  ['bjp',
#   'government',
#   'strip',
#   'muslims',
#   'christians',
#   'citizenship',
#   'boats',
#   'rohingya',
#   'burma'],
#  ['etiquette', 'wishing', 'jehovah', 'witness', 'birthday'],
#  ['wants',
#   'open',
#   'fm',
#   'radio',
#   'station',
#   'city',
#   'india',
#   'cost',
#   'procedure'],
#  ['despise', 'asians'],
#  ['salary', 'income', 'jobs', 'field', 'biotechnology'],
#  ['increase', 'height'],
#  ['effects',
#   'cambodia',
#   'earthquake',
#   'effects',
#   'compare',
#   'kamchatca',
#   'earthquakes'],
#  ['difference', 'sincerity', 'fairness'],
#  ['gaming', 'laptop', '60k', 'inr'],
#  ['review', 'warrior', 'proving', 'grounds'],
#  ['reference', 'book', 'physics', 'class', '11th'],
#  ['national',
#   'institute',
#   'technology',
#   'kurukshetra',
#   'life',
#   'nitk',
#   'surathkal'],
#  ['movies', 'english'],
#  ['causes', 'nightmare'],
#  ['expressionism', 'painting'],
#  ['3d', 'printing', 'work'],
#  ['like', 'attend', 'caltech', 'jeremy', 'ehrhardt'],
#  ['harry', 'horcrux'],
#  ['product',
#   'manager',
#   'apm',
#   'programs',
#   '20s',
#   'join',
#   'learn',
#   'product',
#   'management',
#   'career',
#   'company'],
#  ['number', 'skype'],
#  ['war', 'india', 'pakistan', 'uri', 'attack', 'effects'],
#  ['ronald', 'reagan', 'mannerism', 'speech'],
#  ['war', 'strategies', 'union', 'confederates', 'civil', 'war'],
#  ['fiction', 'novel'],
#  ['recover', 'email', 'forgot', 'password'],
#  ['demonetisation', 'results', 'gdp'],
#  ['heard', 'travel', 'hacking'],
#  ['difference', 'love', 'pity'],
#  ['hiring', 'process', 'republic', 'bank'],
#  ['google', 'helps', 'spam', 'ranking', 'adjustment', 'search', 'results'],
#  ['watch', 'gonulcelen', 'subtitles'],
#  ['usa', 'country', 'world'],
#  ['obtain', 'ulcer', 'pain', 'relief'],
#  ['think', 'china', 'food'],
#  ['taking', 'advantage', 'mean'],
#  ['cry'],
#  ['girls', 'like', 'stick', 'tongues', 'taking', 'pictures'],
#  ['find', 'ending', 'depressing'],
#  ['mind', 'blowing', 'computer', 'tools', 'exist', 'people', 'know'],
#  ['toothbrush', 'applying', 'toothpaste'],
#  ['question', 'marked', 'needing', 'imrovement'],
#  ['difference', 'state', 'buffer', 'state'],
#  ['mineral', 'holds', 'charge'],
#  ['mystery', 'universe'],
#  ['alternative', 'machine', 'learning'],
#  ['china',
#   'block',
#   'sanctions',
#   'un',
#   'jaish',
#   'e',
#   'mohammad',
#   'jem',
#   'chief',
#   'masood',
#   'azhar'],
#  ['mean', 'budget'],
#  ['amounts', 'vitamin', 'c', 'cause', 'miscarriage'],
#  ['work', 'asahi', 'india', 'glass', 'pay', 'scale', 'years'],
#  ['access', 'torbox', 'india'],
#  ['yakshini', 'mantras'],
#  ['party', 'talks'],
#  ['register', 'domain', 'site', 'email'],
#  ['men', 'attracted', 'women'],
#  ['structure', 'shape', 'compression'],
#  ['rohingya', 'muslims'],
#  ['matter', 'humans'],
#  ['exocytosis', 'endocytosis', 'examples', 'transport'],
#  ['hair', 'head'],
#  ['life', 'retirement'],
#  ['stance', 'pakistan'],
#  ['websites', 'escorts'],
#  ['polo', 'diesel', 'i', 'petrol'],
#  ['hole', 'mass'],
#  ['morgan', 'freeman', 'says', 'way', 'stop', 'racism', 'stop', 'talking'],
#  ['fab', 'offer', 'employees', 'stock', 'options', 'rsus'],
#  ['review', 'site', 'waveclues'],
#  ['ways',
#   'distribute',
#   'looking',
#   'pencils',
#   'students',
#   'student',
#   'gets',
#   'pencil'],
#  ['cost', 'hire', 'jerry', 'seinfeld', 'hours'],
#  ['days', 'rabies', 'vaccine', 'exposure'],
#  ['years', 'britain', 'ruled', 'india'],
#  ['stop', 'working'],
#  ['red', 'keys', 'oitnb'],
#  ['age', 'lose', 'virginity'],
#  [],
#  ['snoke', 'darth', 'maul'],
#  ['monetize',
#   'youtube',
#   'videos',
#   'upload',
#   'copyright',
#   'content',
#   'chances',
#   'google',
#   'block',
#   'account'],
#  ['switch', 'canon', '6d', 'leica', 'd', 'lux'],
#  ['quora', 'website', 'look', 'members', 'quora', 'moderation'],
#  ['answer', 'questions', 'quora'],
#  ['funniest', 'joke', 'know'],
#  ['got',
#   'job',
#   'offer',
#   'chelmsford',
#   'essex',
#   'london',
#   'pm',
#   'pay',
#   'tax',
#   'deduction',
#   'advice',
#   'expenses',
#   'couple',
#   'saving'],
#  ['stereotypes', 'united', 'kingdom'],
#  ['use', 'twitter', 'business', 'source'],
#  ['transfer', 'money', 'skrill', 'paypal', 'account'],
#  ['earphone', 'bass'],
#  ['government', 'employees', 'sukanya', 'samrudi', 'yojana'],
#  ['looking', 'speak', 'look', 'speak'],
#  ['engineering', 'fields'],
#  ['life', 'suit', 'stop', 'life', 'abusing'],
#  ['difference', 'salary', 'ctc'],
#  ['prospering', 'towns', 'kerala'],
#  ['way', 'gain', 'confidence'],
#  ['relation', 'gods', 'hindu', 'gods'],
#  ['switch', 'apple', 'music', 'spotify'],
#  ['income', 'fund'],
#  ['live', 'cologne'],
#  ['robert', 'de', 'niro', 'al', 'pacino'],
#  ['people', 'prefer', 'families'],
#  ['animals', 'kiss'],
#  ['deleted', 'instagram', 'chats'],
#  ['stop', 'addicted', 'love'],
#  ['hired', 'eyes', 'ordered', 'follow'],
#  ['find', 'accelerator'],
#  ['check', 'wifi', 'history', 'access', 'android', 'phones'],
#  ['significance',
#   'battle',
#   'somme',
#   'battle',
#   'compare',
#   'contrast',
#   'battle',
#   'rostov'],
#  ['college', 'admissions', 'essay', 've', 'read'],
#  ['happen', 'cover', 'eyes', 'eye', 'patch', 'year', 'patch'],
#  ['pursue', 'things', 'life'],
#  ['ben', 'affleck', 'shine', 'christian', 'bale', 'batman'],
#  ['business', 'start', 'hyderabad'],
#  ['stop'],
#  ['wife', 'lord', 'krishna'],
#  ['combination', 'courses', 'enhance', 'career'],
#  ['screenshot', 'mac', 'laptop'],
#  ['work', 'recruiter'],
#  ['need', 'collecting', 'fulfill'],
#  ['watch', 'tv', 'shows', 'die'],
#  ['chinese'],
#  ['effects', 'demonitization', 'rupees', 'notes', 'estate', 'sector'],
#  ['way', 'billionaire($'],
#  ['people', 'lectures', 'conduct', 'workshop', 'india', 'colleges'],
#  ['way', 'start', 'learning', 'robotics'],
#  ['people', 'hate', 'hillary', 'clinton'],
#  ['women',
#   'periods',
#   'regarded',
#   'prevented',
#   'taking',
#   'actived',
#   'rituals',
#   'hinduism'],
#  ['atheism', 'lack', 'belief', 'gods', 'term', 'belief', 'god'],
#  ['jack', 'dorsey'],
#  ['quotes', 'lessons', 'assassin', 'creed', 'series'],
#  ['printers', 'use', 'color', 'ink', 'printing', 'documents'],
#  ['creativity'],
#  ['hillary',
#   'clinton',
#   'continue',
#   'campaign',
#   'democratic',
#   'party',
#   'choose',
#   'candidate'],
#  ['headphones',
#   'work',
#   'antenna',
#   'play',
#   'fm',
#   'radio',
#   'channels',
#   'phones',
#   'companies',
#   'install',
#   'inbuilt',
#   'antenna',
#   'phones',
#   'play',
#   'fm',
#   'headphones'],
#  ['career',
#   'growth',
#   'technologies',
#   'automation',
#   'engineers',
#   'automation',
#   'tools'],
#  ['disadvantages', 'listing', 'company', 'nse'],
#  ['derivatives', 'object', 'position', 'respect', 'time'],
#  ['neutron', 'star'],
#  ['got', 'gpa', 'universities', 'harvard'],
#  ['way', 'trade', 'options'],
#  ['utilize', 'time', 'avoid', 'depression'],
#  ['learn', 'computer', 'security'],
#  ['earn', 'quora'],
#  ['puk', 'code'],
#  ['find', 'job', 'japan'],
#  ['examples', 'sentences', 'word', 'hysteria'],
#  ['dollar', 'lottery', 'jackpot'],
#  ['drive', 'road', 'hana', 'given', 'turns'],
#  ['create', 'shell', 'terminal', 'c', 'programming', 'linux', 'terminal'],
#  ['cognition', 'affect', 'perception'],
#  ['tqwl', 'ckwl', 'waiting', 'list'],
#  ['world', 'place', 'live', 'generations'],
#  ['champions', 'league', 'legends'],
#  ['drinking', 'liters', 'water', 'day'],
#  ['water',
#   'great',
#   'lakes',
#   'come',
#   'lakes',
#   'wildlife',
#   'compare',
#   'lake',
#   'prespa'],
#  ['porn', 'stars', 'watch', 'porn'],
#  ['trump', 'supporters', 'feel', 'way', 'walking', 'promises'],
#  ['opinions'],
#  ['train', 'months', 'pitbull'],
#  ['jump', 'rope', 'minutes', 'calories', 'use'],
#  ['test', 'series', 'gate', 'cs', 'stream'],
#  ['material', 'understanding', 'analysis'],
#  ['temperament', 'bullmastiff', 'husky', 'mix'],
#  ['balls', 'weigh', 'weight', 'know', 'find', 'ball', 'weighs'],
#  ['play', 'raisin', 'sun', 'walter', 'ad', 'beneatha', 'argue'],
#  ['signs', 'person', 'playing'],
#  ['energy', 'created', 'expansion', 'infinite', 'created'],
#  ['book', 'published'],
#  ['disrupting', 'bloomberg'],
#  ['flash', 'run'],
#  ['way', 'invest', 'profits', 'period', 'time', 'months'],
#  ['implementation', 'gst', 'bill', 'impact', 'lives', 'people'],
#  ['recover', 'gmail', 'password'],
#  ['illness', 'diagnosed'],
#  ['knee', 'pain', 'year', 'girl'],
#  ['qualities', 'leader'],
#  ['difference', 'bay', 'gulf', 'straits'],
#  ['modi', 'win'],
#  ['open', 'dmart', 'store', 'india', 'franchise'],
#  ['youtube', 'channels', 'learn', 'medicine'],
#  ['swami', 'vivekananda', 'eat', 'egg', 'journey', 'world'],
#  ['happen', 'cancel', 'tqwl', 'tickets', 'charting'],
#  ['common', 'core', 'initiative', 'standards', 'pros', 'cons'],
#  ['choose', 'journal', 'publish', 'paper'],
#  ['new', 'year', 'resolutions'],
#  ['dream'],
#  ['slavs', 'squat'],
#  ['marks', 'score', 'aiims', 'rank'],
#  ['operating',
#   'room',
#   'surgeons',
#   'experience',
#   'disagree',
#   'procedure',
#   'tie',
#   'broken'],
#  ['months', 'gain', 'knowledge', 'developing', 'android', 'apps', 'scratch'],
#  ['love', 'body', 'guy'],
#  ['rights', 'prisoner'],
#  ['gems', 'clash', 'clans'],
#  ['apps', 'word', 'lens'],
#  ['ex',
#   'girlfriend',
#   'suffering',
#   'malaria',
#   'urge',
#   'visiting',
#   'placements',
#   'idea'],
#  ['way', 'traffic', 'website'],
#  ['feel', 'upvotes', 'answer', 'quora'],
#  ['films', 'tv', 'shows', 'feature', 'protagonists'],
#  ['love', 'wait', 'love'],
#  ['people', 'die'],
#  ['clothes', 'polyester', 'cotton'],
#  ['bone', 'marrow'],
#  ['slave', 'reddice'],
#  ['body', 'float', 'surface', 'drowning'],
#  ['friend', 'talked', 'years', 'miss'],
#  ['travelling', 'region', 'immerse', 'cities', 'cities', 'cram'],
#  ['money', 'cost'],
#  ['buy', 'quality', 'customized', 'cupcakes', 'gold', 'coast'],
#  ['plan'],
#  ['war', 'india', 'pakistan', 'win'],
#  ['deal', 'fear', 'dying'],
#  ['estimated', 'cost', 'repairing', 'cracked', 'screen', 'iphone'],
#  ['products', 'innovations', 'mcdonald', 'coming'],
#  ['end', 'universe', 'universe', 'infinite'],
#  [],
#  ['funds', 'raise'],
#  ['anna', 'hazare', 'think', 'pm', 'modi'],
#  ['effect', 'banning', 'notes', 'stock', 'markets', 'india'],
#  ['contractions', 'differ', 'contractions'],
#  ['puppet', 'yoda', 'episode', 'suck'],
#  ['platforms', 'post', 'ads', 'beer', 'money', 'opportunity'],
#  ['meaning', 'life'],
#  ['start', 'business'],
#  ['acquire', 'morality'],
#  ['need', 'friends'],
#  ['exist'],
#  ['hollywood', 'thriller', 'movies'],
#  ['repeat', 'year', 'college', 'find', 'college', 'year', 'course'],
#  ['diesel', 'pumped', 'filling', 'station', 'motor', 'igniting', 'fire'],
#  ['job', 'possibilities', 'exist', 'bachelors', 'homeland', 'security'],
#  ['books', 'understand', 'calculus'],
#  ['break'],
#  ['use', 'jio', 'sim', 'iphone'],
#  ['rules', 'usa'],
#  ['answer', 'years', 'gap', 'job', 'interview'],
#  ['songs', 'voices'],
#  ['predict', 'birth', 'chart'],
#  ['birth', 'functions'],
#  ['saying', 'mean', 'trust', 'salt', 'looks', 'sugar'],
#  ['countries', 'prevent', 'war'],
#  ['billionaire'],
#  ['learn', 'web', 'design'],
#  ['line',
#   'calender',
#   'scheduling',
#   'booking',
#   'system',
#   'allows',
#   'availability',
#   'customers',
#   'request',
#   'meet',
#   'accept',
#   'request',
#   'appointment',
#   'pops',
#   'calendars',
#   'reminders',
#   'automated'],
#  ['gdp', 'affected', 'banning', 'rupees', 'notes'],
#  ['understanding', 'death'],
#  ['dogs', 'considered', 'omnivores'],
#  ['cheated', 'relationship'],
#  ['know', 'blocked', 'texts'],
#  ['foods', 'eaten', 'country'],
#  ['banker'],
#  ['journalism'],
#  ['increase', 'concentration'],
#  ['sent', 'invitations', 'linkedin', 'invitations'],
#  ['pros', 'cons', 'dog'],
#  ['difference', 'deism', 'agnosticism'],
#  ['porn', 'stars', 'masturbate', 'ejaculate'],
#  ['cgpa', 'require', 'admission', 'mtech', 'cse', 'iit', 'madras'],
#  ['reason', 'people', 'cry'],
#  ['facts', 'earth', 'crust'],
#  ['isro', 'use', 'friction', 'stir', 'welding', 'technology'],
#  ['wish',
#   'simulate',
#   'location',
#   'app',
#   'running',
#   'ios',
#   'device',
#   'fake',
#   'gps',
#   'location',
#   'ios',
#   'jailbreaking'],
#  ['way', 'quit', 'smoking'],
#  ['programing', 'language', 'tcs'],
#  ['earthquake', 'homes'],
#  ['kristen', 'stewart', 'actress'],
#  ['guys', 'try', 'look', 'girls', 'find'],
#  ['sugar', 'daddy', 'websites'],
#  ['vtu', '1st', 'exam', 'time', 'table', 'dec'],
#  ['phone', 'buy', '15k'],
#  ['start', 'business'],
#  ['death', 'experience', 've'],
#  ['getting', 'fleas', 'dogs'],
#  ['year', 'letter', 'j', 'come'],
#  ['harvard', 'college', 'courses', 'shopping', 'advice', 'classes'],
#  ['send', 'message', 'android', 'phone', 'android', 'phone', 'bluetooth'],
#  ['books', 'written'],
#  ['universities', 'sigma', 'designs', 'recruit', 'grads', 'majors', 'looking'],
#  ['m.phil', 'india', 'masters', 'uk', 'ma', 'psychology'],
#  ['universities',
#   'powell',
#   'industries',
#   'recruit',
#   'grads',
#   'majors',
#   'looking'],
#  ['movie', 'posters', 'come'],
#  ['examples', 'deuteromycota', 'formed'],
#  ['racist'],
#  ['differences'],
#  ['canada', 'geese'],
#  ['find', 'zeros', 'function', 'math]f(x)=\\dfrac{1}{2}x^{3}-3x[/math'],
#  ['edit', 'devices', 'google', 'play', 'account'],
#  ['speaker'],
#  ['write', 'letter', 'mr.', 'narendra', 'modi'],
#  ['election', 'donald', 'trump', 'ted', 'cruz'],
#  ['bastards', 'snow'],
#  ['think', 'bermuda', 'triangle'],
#  ['girls', 'guys'],
#  ['lived', 'house'],
#  ['boy', 'girl', 'called', 'years', 'years', 'years'],
#  ['debeak', 'cockerels', 'months'],
#  ['overcome', 'anxiety'],
#  ['avoid', 'whey', 'yogurt'],
#  ['m', 'love', 'friend', 'guy', 'girlfriend', 'want', 'tell'],
#  ['university', 'germany', 'ms'],
#  ['maintain', 'peace', 'mind'],
#  ['car', 'build', 'quality', 'india'],
#  ['massaging', 'temples', 'soothe', 'migraine', 'headache'],
#  ['kmc', 'manipal', 'kmc', 'mangalore'],
#  ['bestfriend', 'ignoring'],
#  ['sensors',
#   'acer',
#   'liquid',
#   'z630s',
#   'android',
#   'smart',
#   'phone',
#   'cpu',
#   'z',
#   'app'],
#  ['motivation', 'learn', 'language'],
#  ['assessment', 'companies', 'india'],
#  ['mean', 'emoticon'],
#  ['discharge', 'pregnancy', 'causes'],
#  ['ways', 'finger'],
#  ['scientists', 'work'],
#  ['sponsored', 'candidates', 'shortlisted', 'cmc'],
#  ['wedding', 'ceremony', 'wedding', 'ceremony'],
#  ['condition', 'tourism', 'pakistan'],
#  ['funds'],
#  ['hate', 'shahrukh', 'khan'],
#  ['self', 'help', 'books', 've', 'read'],
#  ['evernote'],
#  ['title', 'continuation', 'gift', 'magi'],
#  ['song', 'lyric', 'prank', 'friend'],
#  ['argued',
#   'gf',
#   'friends',
#   'person',
#   'hit',
#   'said',
#   'm',
#   'control',
#   'freak',
#   'wants',
#   'freedom'],
#  ['pass', 'drug', 'test', 'methamphetamine'],
#  ['start', 'source', 'development'],
#  ['dreams', 'look'],
#  ['cricket', 'players', 'drink', 'tea', 'tea', 'break'],
#  ['entry', 'mit'],
#  ['fetus', 'breathe', 'womb'],
#  ['movies', 'incest', 'scenes'],
#  ['signs', 'guy', 'feelings', 'crush', 'want', 'hides'],
#  ['according', 'international', 'federation', 'robotics', 'robots', 'existed'],
#  ['oberon', 'titania', 'midsummer', 'night', 'dream'],
#  ['regret', 'divorce'],
#  ['dna', 'change', 'time', 'clone', 'years', 'clone', 'hair', 'color'],
#  ['tell', 'girl', 'feelings'],
#  ['donald', 'trump', 'taking', 'cocaine', 'howard', 'dean', 'suggests'],
#  ['order', 'join', 'organisation', 'chance'],
#  ['firm', 'teaching', 'architecture', 'college'],
#  ['comedy', 'nights', 'kapil'],
#  ['sandeep', 'maheshwari', 'quora'],
#  ['monster', 'monster', 'hunter'],
#  ['convince', 'people', 'stop', 'blaspheming', 'holy', 'spirit'],
#  ['stop', 'watching', 'porn'],
#  ['start', 'trusting'],
#  ['bucket', 'list'],
#  ['come', 'porn'],
#  ['car', 'services', 'normal', 'il', 'compared', 'taxis'],
#  ['charged', 'molecules', 'pass', 'lipid', 'cell', 'membrane'],
#  ['feel', 'spouse', 'porn', 'star'],
#  ['hostel', 'booking', 'affiliate', 'program'],
#  ['drive',
#   'brooklyn',
#   'staten',
#   'island',
#   'described',
#   'cities',
#   'tourist',
#   'attractions',
#   'compare',
#   'queens'],
#  ['eat', 'day'],
#  ['calls', 'family', 'members', 'airtel', 'andhra', 'pradesh'],
#  ['hillary', 'clinton', 'election'],
#  ['use', 'vicks', 'vapor', 'rub', 'nose'],
#  ['start', 'prepare', 'ugc', 'english', 'literature', 'syllabus'],
#  ['europeans', 'protein', 'columbian', 'exchange'],
#  ['forum', 'designers'],
#  ['alex', 'jones'],
#  ['learn', 'angularjs', 'angularjs', 'know', 'typescript'],
#  ['fall', 'days'],
#  ['marvel', 'movies', 'included', 'stan', 'lee', 'cameos'],
#  ['views',
#   'modi',
#   'governments',
#   'decision',
#   'demonetize',
#   'notes',
#   'affect',
#   'economy'],
#  ['10/', 'label', 'mad', 'hatter', 'hat', 'mean'],
#  ['wrote', 'kars', 'kids', 'jingle'],
#  ['saltwater', 'taffy', 'candy', 'imported', 'greece'],
#  ['requirements', 'enter', 'mit'],
#  ['answer', 'question', 'quora'],
#  ['israel', 'iran', 'win'],
#  ['learn', 'piano'],
#  ['numbers'],
#  ['t', 'g', 'volte', 'enabled', 'phone'],
#  ['enter', 'email', 'id', 'access', 'recover', 'facebook', 'id'],
#  ['travel', 'light'],
#  ['firefighter'],
#  ['factors',
#   'causes',
#   'data',
#   'inconsistency',
#   'distributed',
#   'platform',
#   'application'],
#  ['differences', 'pocso', 'offenses', 'ipc'],
#  ['alternative', 'word'],
#  ['considered', 'screen', 'nba'],
#  ['excites', 'regain', 'excitement'],
#  ['life', 'lessons', 'batman', 'teaches'],
#  ['stop', 'criminal', 'attempt', 'kidnap', 'escape'],
#  ['sell', 'amazon'],
#  ['daniel', 'ek', 'expect', 'spotify', 'india'],
#  ['books', 'read', '20s'],
#  ['book', 'start', 'gate', 'preparation'],
#  ['phrase', 'love', 'abides', 'death', 'mean'],
#  [],
#  ['touches', 'weed', 'shake', 'hand', 'eat', 'hand'],
#  ['considering',
#   'trend',
#   'information',
#   'technology',
#   'future',
#   'print',
#   'media'],
#  ['recipe', 'chicken', 'pizza'],
#  ['places', 'learn', 'mountaineering', 'india'],
#  ['table', 'tennis', 'balls', 'damage', 'rubbers'],
#  ['xbox', 's', 'connect', 'internet', 'setup', 'solutions'],
#  ['life'],
#  ['gravity', 'theory'],
#  ['fighter', 'pilot', 'required'],
#  ['operation', 'executive', 'salary', 'infosys'],
#  ['cavemen', 'tested'],
#  ['climate', 'change', 'reversed'],
#  ['ask', 'crush', 'number'],
#  ['believe', 'gravitation', 'force', 'exist'],
#  ['mahabharata', 'happen'],
#  ['congress', 'stop', 'presidents', 'starting', 'war'],
#  ['lose', 'pounds', 'month'],
#  ['shounen', 'ai', 'series'],
#  ['police', 'lights'],
#  ['post', 'question', 'marked', 'needing', 'improvement'],
#  ['owns', 'nature'],
#  ['install', 'obb', 'data', 'file', 'android'],
#  ['garbage', 'value', 'garbage', 'value', 'c'],
#  ['prepare', 'software', 'interviews'],
#  ['rahul', 'gandhi', 'chance', 'pm', 'india', 'modi'],
#  ['noon', 'pm'],
#  ['difference', 'comet', 'asteroid'],
#  ['chocolate', 'milk'],
#  ['study'],
#  ['country', 'education', 'work'],
#  ['painting', 'image'],
#  ['highways', 'california', 'compared', 'highways', 'tennessee'],
#  ['universe'],
#  ['growing', 'hair', 'chemical', 'change'],
#  ['difference', 'culture', 'history']]

# %%
sentence = []
sentences = []


def token_2_sentence(normalized_data):
    """Join the tokens in each list with space to form a sentence"""
    for i in normalized_data:
      sentence = " ".join(i)
      sentences.append(sentence)
      sentence = [] 
    return sentences
    
sentences_list = token_2_sentence(normalized_data)

# %%
# Display cleaned questions
sentences_list
# Out:
# ['step step guide invest share market india',
#  'story kohinoor koh noor diamond',
#  'increase speed internet connection vpn',
#  'solve',
#  'dissolve water sugar salt methane carbon oxide',
#  'astrology capricorn sun cap moon cap rising',
#  'buy tiago',
#  'geologist',
#  'use',
#  'motorola company hack charter motorolla dcx',
#  'method find separation slits fresnel biprism',
#  'read find youtube comments',
#  'physics learn',
#  'experience',
#  'laws change status student visa card compare immigration laws canada',
#  'trump presidency mean master students f visa',
#  'manipulation mean',
#  'girls want friends guy reject',
#  'quora users posting questions answered google',
#  'marketing institution banglore',
#  'rockets look',
#  'causing',
#  'questions ask quora',
#  'kv hp',
#  'mean time look clock numbers',
#  'tips making job interview process medicines',
#  'web application',
#  'society place importance sports',
#  'way money',
#  'prepare law',
#  'thing like',
#  'cares nose gets night',
#  'game thrones villain mercy',
#  'united states government blacklist employment united states citizens views',
#  'travel website spain',
#  'people think obama try guns',
#  'improve skills entrepreneur years',
#  'girlfriend asks boyfriend choose makes want reply',
#  'prepare upsc',
#  'stall speed aoa f- wings swept',
#  'slavs squat',
#  'expect confirmation mail',
#  'month day trading',
#  'kid rebel worth run',
#  'universities rexnord grads majors looking',
#  'way increase instagram followers',
#  'darth vader fought darth maul star wars legends',
#  'stages breaking couple mean happens breaking',
#  'examples products oil',
#  'friends',
#  'career launcher rbi grade b preparation',
#  'blu ray play dvd player',
#  '',
#  'thing ve eaten',
#  'gst affects cas tax officers',
#  'rsi',
#  'friend',
#  'rap songs dance',
#  'logged gmail remember gmail password realized recovery email',
#  'ways learn french',
#  'download content kickass torrent registration',
#  'ring iris eye',
#  'harry potter book harry potter cursed child',
#  '',
#  'find family office database',
#  'java programming learn java programming language',
#  'book',
#  'store energy produced lightning',
#  'review performance testing',
#  'cost privacy germany come lost gain privacy',
#  'types immunity',
#  'personality disorder',
#  'speak english',
#  'quickbooks auto data recovery support phone number recover corrupted data files',
#  'gambler time reach level',
#  'fire bullet aircraft going bullet bullet going',
#  'prevent breast cancer',
#  'log gmail account friend phone',
#  'money internet',
#  'purpose life',
#  'bjp government strip muslims christians citizenship boats rohingya burma',
#  'etiquette wishing jehovah witness birthday',
#  'wants open fm radio station city india cost procedure',
#  'despise asians',
#  'salary income jobs field biotechnology',
#  'increase height',
#  'effects cambodia earthquake effects compare kamchatca earthquakes',
#  'difference sincerity fairness',
#  'gaming laptop 60k inr',
#  'review warrior proving grounds',
#  'reference book physics class 11th',
#  'national institute technology kurukshetra life nitk surathkal',
#  'movies english',
#  'causes nightmare',
#  'expressionism painting',
#  '3d printing work',
#  'like attend caltech jeremy ehrhardt',
#  'harry horcrux',
#  'product manager apm programs 20s join learn product management career company',
#  'number skype',
#  'war india pakistan uri attack effects',
#  'ronald reagan mannerism speech',
#  'war strategies union confederates civil war',
#  'fiction novel',
#  'recover email forgot password',
#  'demonetisation results gdp',
#  'heard travel hacking',
#  'difference love pity',
#  'hiring process republic bank',
#  'google helps spam ranking adjustment search results',
#  'watch gonulcelen subtitles',
#  'usa country world',
#  'obtain ulcer pain relief',
#  'think china food',
#  'taking advantage mean',
#  'cry',
#  'girls like stick tongues taking pictures',
#  'find ending depressing',
#  'mind blowing computer tools exist people know',
#  'toothbrush applying toothpaste',
#  'question marked needing imrovement',
#  'difference state buffer state',
#  'mineral holds charge',
#  'mystery universe',
#  'alternative machine learning',
#  'china block sanctions un jaish e mohammad jem chief masood azhar',
#  'mean budget',
#  'amounts vitamin c cause miscarriage',
#  'work asahi india glass pay scale years',
#  'access torbox india',
#  'yakshini mantras',
#  'party talks',
#  'register domain site email',
#  'men attracted women',
#  'structure shape compression',
#  'rohingya muslims',
#  'matter humans',
#  'exocytosis endocytosis examples transport',
#  'hair head',
#  'life retirement',
#  'stance pakistan',
#  'websites escorts',
#  'polo diesel i petrol',
#  'hole mass',
#  'morgan freeman says way stop racism stop talking',
#  'fab offer employees stock options rsus',
#  'review site waveclues',
#  'ways distribute looking pencils students student gets pencil',
#  'cost hire jerry seinfeld hours',
#  'days rabies vaccine exposure',
#  'years britain ruled india',
#  'stop working',
#  'red keys oitnb',
#  'age lose virginity',
#  '',
#  'snoke darth maul',
#  'monetize youtube videos upload copyright content chances google block account',
#  'switch canon 6d leica d lux',
#  'quora website look members quora moderation',
#  'answer questions quora',
#  'funniest joke know',
#  'got job offer chelmsford essex london pm pay tax deduction advice expenses couple saving',
#  'stereotypes united kingdom',
#  'use twitter business source',
#  'transfer money skrill paypal account',
#  'earphone bass',
#  'government employees sukanya samrudi yojana',
#  'looking speak look speak',
#  'engineering fields',
#  'life suit stop life abusing',
#  'difference salary ctc',
#  'prospering towns kerala',
#  'way gain confidence',
#  'relation gods hindu gods',
#  'switch apple music spotify',
#  'income fund',
#  'live cologne',
#  'robert de niro al pacino',
#  'people prefer families',
#  'animals kiss',
#  'deleted instagram chats',
#  'stop addicted love',
#  'hired eyes ordered follow',
#  'find accelerator',
#  'check wifi history access android phones',
#  'significance battle somme battle compare contrast battle rostov',
#  'college admissions essay ve read',
#  'happen cover eyes eye patch year patch',
#  'pursue things life',
#  'ben affleck shine christian bale batman',
#  'business start hyderabad',
#  'stop',
#  'wife lord krishna',
#  'combination courses enhance career',
#  'screenshot mac laptop',
#  'work recruiter',
#  'need collecting fulfill',
#  'watch tv shows die',
#  'chinese',
#  'effects demonitization rupees notes estate sector',
#  'way billionaire($',
#  'people lectures conduct workshop india colleges',
#  'way start learning robotics',
#  'people hate hillary clinton',
#  'women periods regarded prevented taking actived rituals hinduism',
#  'atheism lack belief gods term belief god',
#  'jack dorsey',
#  'quotes lessons assassin creed series',
#  'printers use color ink printing documents',
#  'creativity',
#  'hillary clinton continue campaign democratic party choose candidate',
#  'headphones work antenna play fm radio channels phones companies install inbuilt antenna phones play fm headphones',
#  'career growth technologies automation engineers automation tools',
#  'disadvantages listing company nse',
#  'derivatives object position respect time',
#  'neutron star',
#  'got gpa universities harvard',
#  'way trade options',
#  'utilize time avoid depression',
#  'learn computer security',
#  'earn quora',
#  'puk code',
#  'find job japan',
#  'examples sentences word hysteria',
#  'dollar lottery jackpot',
#  'drive road hana given turns',
#  'create shell terminal c programming linux terminal',
#  'cognition affect perception',
#  'tqwl ckwl waiting list',
#  'world place live generations',
#  'champions league legends',
#  'drinking liters water day',
#  'water great lakes come lakes wildlife compare lake prespa',
#  'porn stars watch porn',
#  'trump supporters feel way walking promises',
#  'opinions',
#  'train months pitbull',
#  'jump rope minutes calories use',
#  'test series gate cs stream',
#  'material understanding analysis',
#  'temperament bullmastiff husky mix',
#  'balls weigh weight know find ball weighs',
#  'play raisin sun walter ad beneatha argue',
#  'signs person playing',
#  'energy created expansion infinite created',
#  'book published',
#  'disrupting bloomberg',
#  'flash run',
#  'way invest profits period time months',
#  'implementation gst bill impact lives people',
#  'recover gmail password',
#  'illness diagnosed',
#  'knee pain year girl',
#  'qualities leader',
#  'difference bay gulf straits',
#  'modi win',
#  'open dmart store india franchise',
#  'youtube channels learn medicine',
#  'swami vivekananda eat egg journey world',
#  'happen cancel tqwl tickets charting',
#  'common core initiative standards pros cons',
#  'choose journal publish paper',
#  'new year resolutions',
#  'dream',
#  'slavs squat',
#  'marks score aiims rank',
#  'operating room surgeons experience disagree procedure tie broken',
#  'months gain knowledge developing android apps scratch',
#  'love body guy',
#  'rights prisoner',
#  'gems clash clans',
#  'apps word lens',
#  'ex girlfriend suffering malaria urge visiting placements idea',
#  'way traffic website',
#  'feel upvotes answer quora',
#  'films tv shows feature protagonists',
#  'love wait love',
#  'people die',
#  'clothes polyester cotton',
#  'bone marrow',
#  'slave reddice',
#  'body float surface drowning',
#  'friend talked years miss',
#  'travelling region immerse cities cities cram',
#  'money cost',
#  'buy quality customized cupcakes gold coast',
#  'plan',
#  'war india pakistan win',
#  'deal fear dying',
#  'estimated cost repairing cracked screen iphone',
#  'products innovations mcdonald coming',
#  'end universe universe infinite',
#  '',
#  'funds raise',
#  'anna hazare think pm modi',
#  'effect banning notes stock markets india',
#  'contractions differ contractions',
#  'puppet yoda episode suck',
#  'platforms post ads beer money opportunity',
#  'meaning life',
#  'start business',
#  'acquire morality',
#  'need friends',
#  'exist',
#  'hollywood thriller movies',
#  'repeat year college find college year course',
#  'diesel pumped filling station motor igniting fire',
#  'job possibilities exist bachelors homeland security',
#  'books understand calculus',
#  'break',
#  'use jio sim iphone',
#  'rules usa',
#  'answer years gap job interview',
#  'songs voices',
#  'predict birth chart',
#  'birth functions',
#  'saying mean trust salt looks sugar',
#  'countries prevent war',
#  'billionaire',
#  'learn web design',
#  'line calender scheduling booking system allows availability customers request meet accept request appointment pops calendars reminders automated',
#  'gdp affected banning rupees notes',
#  'understanding death',
#  'dogs considered omnivores',
#  'cheated relationship',
#  'know blocked texts',
#  'foods eaten country',
#  'banker',
#  'journalism',
#  'increase concentration',
#  'sent invitations linkedin invitations',
#  'pros cons dog',
#  'difference deism agnosticism',
#  'porn stars masturbate ejaculate',
#  'cgpa require admission mtech cse iit madras',
#  'reason people cry',
#  'facts earth crust',
#  'isro use friction stir welding technology',
#  'wish simulate location app running ios device fake gps location ios jailbreaking',
#  'way quit smoking',
#  'programing language tcs',
#  'earthquake homes',
#  'kristen stewart actress',
#  'guys try look girls find',
#  'sugar daddy websites',
#  'vtu 1st exam time table dec',
#  'phone buy 15k',
#  'start business',
#  'death experience ve',
#  'getting fleas dogs',
#  'year letter j come',
#  'harvard college courses shopping advice classes',
#  'send message android phone android phone bluetooth',
#  'books written',
#  'universities sigma designs recruit grads majors looking',
#  'm.phil india masters uk ma psychology',
#  'universities powell industries recruit grads majors looking',
#  'movie posters come',
#  'examples deuteromycota formed',
#  'racist',
#  'differences',
#  'canada geese',
#  'find zeros function math]f(x)=\\dfrac{1}{2}x^{3}-3x[/math',
#  'edit devices google play account',
#  'speaker',
#  'write letter mr. narendra modi',
#  'election donald trump ted cruz',
#  'bastards snow',
#  'think bermuda triangle',
#  'girls guys',
#  'lived house',
#  'boy girl called years years years',
#  'debeak cockerels months',
#  'overcome anxiety',
#  'avoid whey yogurt',
#  'm love friend guy girlfriend want tell',
#  'university germany ms',
#  'maintain peace mind',
#  'car build quality india',
#  'massaging temples soothe migraine headache',
#  'kmc manipal kmc mangalore',
#  'bestfriend ignoring',
#  'sensors acer liquid z630s android smart phone cpu z app',
#  'motivation learn language',
#  'assessment companies india',
#  'mean emoticon',
#  'discharge pregnancy causes',
#  'ways finger',
#  'scientists work',
#  'sponsored candidates shortlisted cmc',
#  'wedding ceremony wedding ceremony',
#  'condition tourism pakistan',
#  'funds',
#  'hate shahrukh khan',
#  'self help books ve read',
#  'evernote',
#  'title continuation gift magi',
#  'song lyric prank friend',
#  'argued gf friends person hit said m control freak wants freedom',
#  'pass drug test methamphetamine',
#  'start source development',
#  'dreams look',
#  'cricket players drink tea tea break',
#  'entry mit',
#  'fetus breathe womb',
#  'movies incest scenes',
#  'signs guy feelings crush want hides',
#  'according international federation robotics robots existed',
#  'oberon titania midsummer night dream',
#  'regret divorce',
#  'dna change time clone years clone hair color',
#  'tell girl feelings',
#  'donald trump taking cocaine howard dean suggests',
#  'order join organisation chance',
#  'firm teaching architecture college',
#  'comedy nights kapil',
#  'sandeep maheshwari quora',
#  'monster monster hunter',
#  'convince people stop blaspheming holy spirit',
#  'stop watching porn',
#  'start trusting',
#  'bucket list',
#  'come porn',
#  'car services normal il compared taxis',
#  'charged molecules pass lipid cell membrane',
#  'feel spouse porn star',
#  'hostel booking affiliate program',
#  'drive brooklyn staten island described cities tourist attractions compare queens',
#  'eat day',
#  'calls family members airtel andhra pradesh',
#  'hillary clinton election',
#  'use vicks vapor rub nose',
#  'start prepare ugc english literature syllabus',
#  'europeans protein columbian exchange',
#  'forum designers',
#  'alex jones',
#  'learn angularjs angularjs know typescript',
#  'fall days',
#  'marvel movies included stan lee cameos',
#  'views modi governments decision demonetize notes affect economy',
#  '10/ label mad hatter hat mean',
#  'wrote kars kids jingle',
#  'saltwater taffy candy imported greece',
#  'requirements enter mit',
#  'answer question quora',
#  'israel iran win',
#  'learn piano',
#  'numbers',
#  't g volte enabled phone',
#  'enter email id access recover facebook id',
#  'travel light',
#  'firefighter',
#  'factors causes data inconsistency distributed platform application',
#  'differences pocso offenses ipc',
#  'alternative word',
#  'considered screen nba',
#  'excites regain excitement',
#  'life lessons batman teaches',
#  'stop criminal attempt kidnap escape',
#  'sell amazon',
#  'daniel ek expect spotify india',
#  'books read 20s',
#  'book start gate preparation',
#  'phrase love abides death mean',
#  '',
#  'touches weed shake hand eat hand',
#  'considering trend information technology future print media',
#  'recipe chicken pizza',
#  'places learn mountaineering india',
#  'table tennis balls damage rubbers',
#  'xbox s connect internet setup solutions',
#  'life',
#  'gravity theory',
#  'fighter pilot required',
#  'operation executive salary infosys',
#  'cavemen tested',
#  'climate change reversed',
#  'ask crush number',
#  'believe gravitation force exist',
#  'mahabharata happen',
#  'congress stop presidents starting war',
#  'lose pounds month',
#  'shounen ai series',
#  'police lights',
#  'post question marked needing improvement',
#  'owns nature',
#  'install obb data file android',
#  'garbage value garbage value c',
#  'prepare software interviews',
#  'rahul gandhi chance pm india modi',
#  'noon pm',
#  'difference comet asteroid',
#  'chocolate milk',
#  'study',
#  'country education work',
#  'painting image',
#  'highways california compared highways tennessee',
#  'universe',
#  'growing hair chemical change',
#  'difference culture history']

# %% [markdown]
# ## LDA with term frequency ##

# %%
#https://medium.com/mlreview/topic-modeling-with-scikit-learn-e80d33668730
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print( "Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))


documents = sentences

no_features = 1000


# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(max_df=0.98, min_df=3, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents)
tf_feature_names = tf_vectorizer.get_feature_names()

no_topics = 20


# Run LDA
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

no_top_words = 10
print()
print("LDA topics")
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# LDA topics
# Topic 0:
# porn come gmail question months password change compare stop star
# Topic 1:
# google increase account ways play youtube internet language books way
# Topic 2:
# day quora life look website movies technology increase country death
# Topic 3:
# mean friends trump sugar want taking girls guy ve books
# Topic 4:
# life technology internet watch stop experience death access ve android
# Topic 5:
# india years job pm taking hair change time trump modi
# Topic 6:
# know review hair causes change people exist book modi notes
# Topic 7:
# friend guy email want girlfriend recover love access password choose
# Topic 8:
# data universe modi career win salary experience notes android causes
# Topic 9:
# compare travel effects exist buy notes website girls want work
# Topic 10:
# difference use year college cost love gain girl company come
# Topic 11:
# eat country world death number day mean work love play
# Topic 12:
# start business book happen movies trump sugar notes salary taking
# Topic 13:
# learn books read book language ve star youtube college ways
# Topic 14:
# time looking universities majors grads government ways months business universe
# Topic 15:
# phone look stop series work girls android word money english
# Topic 16:
# play movies work love guy examples friends girlfriend universe girls
# Topic 17:
# quora happen answer questions question year feel look website google
# Topic 18:
# way war prepare pakistan hillary clinton stop start trump choose
# Topic 19:
# people examples think water sugar stop word day internet india

# %%
lda_output = lda.fit_transform(tf)

# %%
print(lda)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='online', learning_offset=50.0,
#                           max_doc_update_iter=100, max_iter=5,
#                           mean_change_tol=0.001, n_components=20, n_jobs=None,
#                           perp_tol=0.1, random_state=0, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
print("Log Likelihood: ", lda.score(tf))
# Out:
# Log Likelihood:  -4937.334991806099

# %%
print("Perplexity: ", lda.perplexity(tf))
# Out:
# Perplexity:  21907.958389461783

# %%
print(lda.get_params())
# Out:
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'online', 'learning_offset': 50.0, 'max_doc_update_iter': 100, 'max_iter': 5, 'mean_change_tol': 0.001, 'n_components': 20, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': 0, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}

# %%
# Define Search Param
search_params = {'n_components': [10, 15, 20, 25, 30], 'learning_decay': [.5, .7, .9]}

# %%
# Init the Model
lda = LatentDirichletAllocation(max_iter=5, learning_method='online', learning_offset=50.,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
# Init Grid Search Class
model = GridSearchCV(lda, param_grid=search_params)

# %%
model.fit(tf)
# Out:
# /home/gargi/.local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=LatentDirichletAllocation(batch_size=128,
#                                                  doc_topic_prior=None,
#                                                  evaluate_every=-1,
#                                                  learning_decay=0.7,
#                                                  learning_method='online',
#                                                  learning_offset=50.0,
#                                                  max_doc_update_iter=100,
#                                                  max_iter=5,
#                                                  mean_change_tol=0.001,
#                                                  n_components=10, n_jobs=None,
#                                                  perp_tol=0.1, random_state=0,
#                                                  topic_word_prior=None,
#                                                  total_samples=1000000.0,
#                                                  verbose=0),
#              iid='warn', n_jobs=None,
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [10, 15, 20, 25, 30]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
best_lda_model = model.best_estimator_

# %%
# Model Parameters
print("Best Model's Params: ", model.best_params_)
# Out:
# Best Model's Params:  {'learning_decay': 0.5, 'n_components': 10}

# %%
# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)
# Out:
# Best Log Likelihood Score:  -1393.205642463917

# %%
# Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(tf))
# Out:
# Model Perplexity:  282.63649075496323

# %%
# Create Document — Topic Matrix
lda_output = best_lda_model.transform(tf)

# %%
# column names
topicnames = ["Topic" + str(i) for i in range(best_lda_model.n_components)]

# %%
# index names
docnames = ["Doc" + str(i) for i in range(len(sentences))]
print((np.round(lda_output, 2)).shape)
# Out:
# (500, 10)

# %%
# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)

# %%
# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic

# %%
# Styling
def color_green(val):
 color = 'green' if val > .1 else 'black'
 return 'color: {col}'.format(col=color)

# %%
def make_bold(val):
 weight = 700 if val > .1 else 400
 return "font-weight: {weight}".format(weight=weight)

# %%
# Apply Style
df_document_topics = df_document_topic.head(100).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style  type="text/css" >
#     #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col5 {
#             color:  green;
#             font-weight:  700;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row0_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row1_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col2 {
#             color:  green;
#             font-weight:  700;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row2_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row3_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col9 {
#             color:  green;
#             font-weight:  700;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row4_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row5_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row5_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row5_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row5_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row5_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row5_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row5_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row5_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row5_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad040499row5_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_14a8b102_98f6_11ea_ad40_105bad04

# %%
# Topic-Keyword Matrix
df_topic_keywords = pd.DataFrame(best_lda_model.components_)

# %%
# Assign Column and Index
df_topic_keywords.columns = tf_vectorizer.get_feature_names()
df_topic_keywords.index = topicnames

# %%
# View
df_topic_keywords.head(100)
# Out:
#           access   account   android    answer      book     books  business  \
# Topic0  0.973612  2.726112  5.971225  0.150628  0.155944  0.159215  0.161505
# Topic1  0.201663  1.022593  0.264526  0.154289  0.155096  0.216758  0.160806
# Topic2  0.146485  0.159058  0.156831  0.146715  0.207690  0.157633  0.154386
# Topic3  0.152522  0.149675  0.161663  0.155229  0.159441  0.160078  0.159394
# Topic4  1.372334  0.159928  0.159640  0.157527  0.148407  0.209307  0.151932
# Topic5  1.013132  0.158018  0.165751  1.119043  0.151303  0.158884  0.155680
# Topic6  0.161983  0.158670  0.158111  3.179994  0.161575  0.155774  0.168778
# Topic7  0.159713  0.160051  0.188378  0.154024  0.171925  0.158159  3.799645
# Topic8  0.155566  0.156043  0.158480  0.156864  4.411312  4.396168  0.156207
# Topic9  0.167892  0.158854  0.153628  0.150594  0.151100  0.160476  0.146868
#
#              buy    career    causes  ...       way      ways   website  \
# Topic0  0.164894  0.159427  0.158714  ...  0.157930  0.154382  0.898765
# Topic1  0.156435  0.152052  0.158369  ...  0.519034  0.158753  0.156490
# Topic2  0.146943  3.364662  3.326178  ...  0.146419  0.152104  1.008746
# Topic3  0.158831  0.159009  0.153673  ...  1.864067  0.156742  0.155950
# Topic4  0.156273  0.152298  0.165226  ...  0.155863  2.973156  0.154038
# Topic5  0.150862  0.159357  0.154065  ...  7.486398  0.155379  1.122881
# Topic6  0.156113  0.152729  0.163049  ...  0.157440  0.152805  0.152099
# Topic7  0.151843  0.162311  0.153748  ...  0.159906  0.165601  0.147124
# Topic8  0.158356  0.167132  0.152622  ...  0.150196  0.151836  0.148355
# Topic9  2.842799  0.155360  0.162660  ...  0.159533  0.158367  0.155617
#
#              win      word      work     world      year     years   youtube
# Topic0  0.160610  0.147024  0.149885  0.156916  0.148789  0.158897  1.011378
# Topic1  0.157608  3.177229  0.149747  0.162040  0.155030  0.200854  0.147202
# Topic2  0.156643  0.159967  0.156824  0.161550  0.151648  0.149802  0.145074
# Topic3  0.156710  0.153496  0.156725  0.150972  0.157811  0.156220  0.154608
# Topic4  0.162188  0.151652  0.154315  0.162685  0.153515  0.156118  1.126064
# Topic5  2.330885  0.156935  0.589658  0.167555  0.149159  8.606199  0.160959
# Topic6  0.150658  0.165457  1.011975  0.152693  4.529206  0.150683  0.161973
# Topic7  0.162060  0.154826  0.149570  2.735106  0.154757  0.162275  0.145765
# Topic8  1.018358  0.150847  0.152523  0.157938  0.159537  0.154095  0.924041
# Topic9  0.157005  0.154478  4.604152  0.160177  1.341787  0.161108  0.165189
#
# [10 rows x 109 columns]

# %%
# Show top n keywords for each topic
def show_topics(vectorizer=tf_vectorizer, lda_model=lda, n_words=20):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

# %%
topic_keywords = show_topics(vectorizer=tf_vectorizer, lda_model=best_lda_model, n_words=15)

# %%
# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#           Word 0      Word 1    Word 2   Word 3      Word 4    Word 5  \
# Topic 0  android       phone      cost   change        hair    months
# Topic 1     life       money  examples     word     hillary   clinton
# Topic 2     love      movies    career   causes    increase  internet
# Topic 3     stop        mean      look    trump     friends    taking
# Topic 4    learn       email      ways  recover  experience     gmail
# Topic 5    india       years       way     time         job  pakistan
# Topic 6    quora        year   college      war        play    happen
# Topic 7    start  difference    people      use    business     think
# Topic 8     know        book     books     read     looking  universe
# Topic 9     porn        work      come  compare       notes       buy
#
#            Word 6        Word 7     Word 8      Word 9     Word 10   Word 11  \
# Topic 0    travel        google    account        gain        play   youtube
# Topic 1  language        choose    account       learn         way      stop
# Topic 2   company          like      quora     english        data     death
# Topic 3     girls        series    prepare         way       sugar      feel
# Topic 4  password         death       star      access     youtube        ve
# Topic 5        pm          girl        win         war        modi   website
# Topic 6    answer        review  questions      number  technology  question
# Topic 7       eat        friend       want  girlfriend        data     world
# Topic 8     exist  universities       modi          ve      majors     grads
# Topic 9     watch         water    effects       sugar     country      feel
#
#             Word 12   Word 13  Word 14
# Topic 0        come    access    gmail
# Topic 1     android     books  company
# Topic 2         guy      look  website
# Topic 3        want       guy     time
# Topic 4     looking      stop    books
# Topic 5      answer    friend   access
# Topic 6        feel      work   google
# Topic 7  government       guy      day
# Topic 8      salary  question  college
# Topic 9        star      year      day

# %%
Topics = ["Topic 1","Topic 2","Topic 3","Topic 4","Topic 5", 
          "Topic 6", "Topic 7", "Topic 8", "Topic 9", "Topic 10"]
df_topic_keywords["Topics"]=Topics
df_topic_keywords
# Out:
#           Word 0      Word 1    Word 2   Word 3      Word 4    Word 5  \
# Topic 0  android       phone      cost   change        hair    months
# Topic 1     life       money  examples     word     hillary   clinton
# Topic 2     love      movies    career   causes    increase  internet
# Topic 3     stop        mean      look    trump     friends    taking
# Topic 4    learn       email      ways  recover  experience     gmail
# Topic 5    india       years       way     time         job  pakistan
# Topic 6    quora        year   college      war        play    happen
# Topic 7    start  difference    people      use    business     think
# Topic 8     know        book     books     read     looking  universe
# Topic 9     porn        work      come  compare       notes       buy
#
#            Word 6        Word 7     Word 8      Word 9     Word 10   Word 11  \
# Topic 0    travel        google    account        gain        play   youtube
# Topic 1  language        choose    account       learn         way      stop
# Topic 2   company          like      quora     english        data     death
# Topic 3     girls        series    prepare         way       sugar      feel
# Topic 4  password         death       star      access     youtube        ve
# Topic 5        pm          girl        win         war        modi   website
# Topic 6    answer        review  questions      number  technology  question
# Topic 7       eat        friend       want  girlfriend        data     world
# Topic 8     exist  universities       modi          ve      majors     grads
# Topic 9     watch         water    effects       sugar     country      feel
#
#             Word 12   Word 13  Word 14    Topics
# Topic 0        come    access    gmail   Topic 1
# Topic 1     android     books  company   Topic 2
# Topic 2         guy      look  website   Topic 3
# Topic 3        want       guy     time   Topic 4
# Topic 4     looking      stop    books   Topic 5
# Topic 5      answer    friend   access   Topic 6
# Topic 6        feel      work   google   Topic 7
# Topic 7  government       guy      day   Topic 8
# Topic 8      salary  question  college   Topic 9
# Topic 9        star      year      day  Topic 10

# %%
test_question = "What is the salary of an Indian Engineer?"

# %%
normalize(test_question)
# Out:
# ['salary', 'engineer']

# %%
test_question
# Out:
# 'What is the salary of an Indian Engineer?'

# %%
test_sentence = token_2_sentence(test_question)

# %%
mytext_4 = tf_vectorizer.transform(test_sentence)

# %%
topic_probability_scores = best_lda_model.transform(mytext_4)

# %%
topic = df_topic_keywords.iloc[np.argmax(topic_probability_scores)%topic_probability_scores.shape[1],1:14].values.tolist()
print(topic)
# Out:
# ['difference', 'people', 'use', 'business', 'think', 'eat', 'friend', 'want', 'girlfriend', 'data', 'world', 'government', 'guy']

# %%
infer_topic = df_topic_keywords.iloc[np.argmax(topic_probability_scores)%topic_probability_scores.shape[1], -1]
print(infer_topic)
# Out:
# Topic 8
